# %% [markdown]
# <a href="https://colab.research.google.com/github/Pallavi-kr6/AnimateItNow/blob/main/DIP_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # STEP1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install rasterio matplotlib numpy

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Update file path (change according to your Drive location)
file_path = '/content/drive/MyDrive/GEE/Dwarka_2021.tif'

with rasterio.open(file_path) as src:
    # Read bands
    blue = src.read(1)   # B2
    green = src.read(2)  # B3
    red = src.read(3)    # B4
    nir = src.read(4)    # B8

# Stack RGB
rgb = np.dstack((red, green, blue))

# Display image
plt.imshow(rgb)
plt.title("Sentinel-2 RGB Image")
plt.axis('off')
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.082].

# %% [markdown]
#  # Step 2: Loading GeoTIFF Files with Rasterio

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Define file path (update with your actual Drive path)
file_path = '/content/drive/MyDrive/GEE/Dwarka_2021.tif'

# Open the GeoTIFF file
with rasterio.open(file_path) as src:
    print('CRS:', src.crs)
    print('Dimensions:', src.width, 'x', src.height)
    print('Number of bands:', src.count)

    # Read bands (convert to float for calculations)
    B2 = src.read(1).astype(float)  # Blue
    B3 = src.read(2).astype(float)  # Green
    B4 = src.read(3).astype(float)  # Red
    B8 = src.read(4).astype(float)  # NIR
# Out:
# CRS: EPSG:4326
# Dimensions: 1155 x 594
# Number of bands: 4
